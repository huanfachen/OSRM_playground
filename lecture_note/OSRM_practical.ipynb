# %% [markdown]
# <a href="https://colab.research.google.com/github/huanfachen/OSRM_playground/blob/main/lecture_note/OSRM_practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OSRM practical
#
# Author: [Huanfa Chen](github.com/huanfachen)

# %%
import datetime
print("Last update:", datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
# Out:
# Last update: 29/06/2022 22:37:35

# %% [markdown]
# This practical will achieve the following objectives:
#
# 1. Set up and configure the OSRM backend on the server;
# 2. Use the routing method from the OSRM;
# 3. Plot the generated route on a map;
# 4. Compare the routes of driving and cycling.

# %%
## install these packages if they are not installed
# !pip install requests
# !pip install folium
# !pip install polyline
# !pip install osrm

# %%
import requests
import folium
import polyline

import osrm
from osrm import Point, simple_route
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/spacetimelab/anaconda3/envs/travel_mode_pred/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ## Set up the OSRM backend

# %% [markdown]
# Note: you can skip this step if the OSRM backend has been set up.
#
# The cell below is the bash commands for downloading and processing the data.
#
# 1. Install docker
# 1. Download the docker image into your computer
# 1. Download the original OSM data for Greater London. You can replace 'greater-london' with other countries/cities
# 1. Process and generate the network data. Note that each OSRM backend instance supports only one mode.
# 1. Start the OSRM server on a selected port (e.g. 5000).

# %%
# %%bash
# ## install docker
# # sudo apt install docker
# ## Download the docker image into your computer
# # docker pull osrm/osrm-backend
# ## go to the folder for storing the osm files
# # cd your_OSRM_folder
# ## Download the original OSM data for Greater London. You can replace 'greater-london' with other countries/cities
# # wget http://download.geofabrik.de/europe/great-britain/greater-london-latest.osm.pbf
# ## Process and generate the network data for different mode
# # sudo docker run -t -v "${PWD}:/data" osrm/osrm-backend osrm-extract -p /opt/car.lua /data/greater-london-latest.osm.pbf
# # sudo docker run -t -v "${PWD}:/data" osrm/osrm-backend osrm-extract -p /opt/bicycle.lua /data/greater-london-latest.osm.pbf
# # sudo docker run -t -v "${PWD}:/data" osrm/osrm-backend osrm-extract -p /opt/foot.lua /data/greater-london-latest.osm.pbf
#
# # sudo docker run -t -v "${PWD}:/data" osrm/osrm-backend osrm-partition /data/greater-london-latest.osrm
# # sudo docker run -t -v "${PWD}:/data" osrm/osrm-backend osrm-customize /data/greater-london-latest.osrm
# ## Start the OSRM server on the port 5000.
# # sudo docker run -t -i -p 5000:5000 -v "${PWD}:/data" osrm/osrm-backend osrm-routed --algorithm mld /data/greater-london-latest.osrm

# %% [markdown]
# ## Connect to the server using a http query

# %%
# the URL of the OSRM server for cycling. Use for this practical only and would expire any time
# Replace it with your server if you have one.
url_server_osm_cycle = "http://47.243.162.93:5000"

# Alternatively, you can use the OSM demo server for practice. Note that it only support the mode of 'driving'. The mode provided by the user is neglected
url_server_osm_driving = "http://router.project-osrm.org"

# %%
# lat and long of the starting and ending point
lat_start, long_start = 51.522002, -0.136170
lat_end, long_end = 51.500284, -0.124760

# %% [markdown]
# We will use a Python package called [osrm](https://github.com/ustroetz/python-osrm) to do the dirty work of formatting the query and interpret the result. This package is called a *wrapper* in some cases.

# %%
## install the package of osrm if needed. You can use pip or other methods
## Note that it has some requirements and dependencies
#!pip install osrm

# %%
# configure the server. You can use either your own server or a demo server from OSM

# note that in osrm.simple_route, the url should not start with 'http://'
mode = "driving"
if url_server_osm_driving.startswith("http://"):
    url_server_osm_no_htpp = url_server_osm_driving.replace("http://", "")
MyConfig = osrm.RequestConfig(url_server_osm_no_htpp + "/route/v1/" + mode)
print(MyConfig)
result = simple_route(
                    Point(latitude=lat_start, longitude=long_start), Point(latitude=lat_end, longitude=long_end),
                    output='route', geometry='wkt', url_config=MyConfig)
print("The length of this route in metres: ", result[0]['distance'])
print("The duration of this route in seconds: ", result[0]['duration'])
# Out:
# router.project-osrm.org/*/v1/driving
# The length of this route in metres:  3227
# The duration of this route in seconds:  543.3

# %% [markdown]
# **result** is a list, with each element representing a returned geometry (the list of points between start and end points)

# %%
# how about on bike?
print("On biking:")
mode = "bike"
if url_server_osm_cycle.startswith("http://"):
    url_server_osm_no_htpp = url_server_osm_cycle.replace("http://", "")
MyConfig = osrm.RequestConfig(url_server_osm_no_htpp + "/route/v1/" + mode)
print(MyConfig)
result = simple_route(
                    Point(latitude=lat_start, longitude=long_start), Point(latitude=lat_end, longitude=long_end),
                    output='route', geometry='wkt', url_config=MyConfig)
print("The length of this route in metres: ", result[0]['distance'])
print("The duration of this route in seconds: ", result[0]['duration'])
# Out:
# On biking:
# 47.243.162.93:5000/*/v1/bike
# The length of this route in metres:  3534.9
# The duration of this route in seconds:  1586.1

# %% [markdown]
# # The request and response in details

# %% [markdown]
# The command above is equivalent to visiting this URL in a browser:
# ```
# http://47.243.162.93:5000/route/v1/driving/-0.136170,51.522002;-0.124760,51.500284?steps=true
# ```
#
# which is in this format:
# ```
# GET/{service}/{version}/{profile}/{coordinates}[.{format}]?option=value&option=value
# ```
#
# Below is a snapshot of the response.

# %% [markdown]
# ![title](../Image/OSRM_response.png)

# %% [markdown]
# The response is in JSON format:
# ```
# {"code":"Ok","routes":[{"geometry":"kruh@q`mfNxBu`@nzEkcCfWmoBgs@}cBpoB}jJtkAoDtzCo`BnlKu{@pbKl^|eLmqFn`E}j@~qL_bGsU{vA_k@mDmkBomCtaA{uC`cBwrBsh@w}@~N}XxvBye@viAewBjwFmvApOxd@`fEs@jr@xo@","legs":[{"steps":[],"distance":87717.5,"duration":5342,"summary":"","weight":5342}],"distance":87717.5,"duration":5342,
# "weight_name":"routability","weight":5342}],"waypoints":[{"hint":"...... }]}
# ```

# %% [markdown]
# # Plot the route on a map

# %%
url = url_server_osm_driving + "/route/v1/driving/-0.136170,51.522002;-0.124760,51.500284?steps=true"
print("URL: ", url)
r = requests.get(url)
res = r.json()
res
# Out:
# URL:  http://router.project-osrm.org/route/v1/driving/-0.136170,51.522002;-0.124760,51.500284?steps=true
# {'code': 'Ok',
#  'routes': [{'geometry': 'g{myHvrYjBjHdTwTbJ}GcCkd@zBiBtF`ChJdLbGqCdIIxEuE|Gs@fCtAfQcG~R?F{G',
#    'legs': [{'steps': [{'geometry': 'g{myHvrYA@EFC@EF',
#        'maneuver': {'bearing_after': 325,
#         'bearing_before': 0,
#         'location': [-0.136277, 51.521956],
#         'modifier': 'right',
#         'type': 'depart'},
#        'mode': 'driving',
#        'driving_side': 'right',
#        'name': 'Howland Mews East',
#        'intersections': [{'out': 0,
#          'entry': [True],
#          'bearings': [325],
#          'location': [-0.136277, 51.521956]}],
#        'weight': 7.2,
#        'duration': 7.2,
#        'distance': 12.5},
#       {'geometry': 'y{myHjsYXv@H\\FJd@vA^bABFFP',
#        'maneuver': {'bearing_after': 233,
#         'bearing_before': 324,
#         'location': [-0.136379, 51.522048],
#         'modifier': 'left',
#         'type': 'turn'},
#        'mode': 'driving',
#        'driving_side': 'right',
#        'name': 'Howland Street',
#        'intersections': [{'out': 2,
#          'in': 1,
#          'entry': [False, False, True, True],
#          'bearings': [60, 150, 240, 330],
#          'location': [-0.136379, 51.522048]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, False, True, False],
#          'bearings': [60, 135, 240, 330],
#          'location': [-0.136808, 51.52187]}],
#        'weight': 21.6,
#        'duration': 21.6,
#        'distance': 119.1},
#       {'geometry': '{wmyHb|YBELMpBuBBAJKjAmAZYJKt@w@hAmADEHIJKBCd@g@d@i@xA{ANOfAgA',
#        'maneuver': {'bearing_after': 146,
#         'bearing_before': 233,
#         'location': [-0.137775, 51.521424],
#         'modifier': 'left',
#         'type': 'turn'},
#        'mode': 'driving',
#        'driving_side': 'right',
#        'name': 'Charlotte Street',
#        'intersections': [{'out': 1,
#          'in': 0,
#          'entry': [False, True, True, True],
#          'bearings': [60, 150, 240, 330],
#          'location': [-0.137775, 51.521424]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [60, 150, 330],
#          'location': [-0.137075, 51.520738]},
#         {'out': 1,
#          'in': 3,
#          'entry': [True, True, True, False],
#          'bearings': [60, 150, 240, 330],
#          'location': [-0.136436, 51.520097]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [60, 150, 330],
#          'location': [-0.13616, 51.519833]},
#         {'out': 1,
#          'in': 3,
#          'entry': [True, True, True, False],
#          'bearings': [60, 150, 240, 330],
#          'location': [-0.135691, 51.519383]},
#         {'out': 0,
#          'in': 2,
#          'entry': [True, False, False],
#          'bearings': [150, 240, 330],
#          'location': [-0.135204, 51.518917]},
#         {'out': 1,
#          'in': 2,
#          'entry': [False, True, False],
#          'bearings': [60, 150, 330],
#          'location': [-0.134741, 51.518471]}],
#        'weight': 61.6,
#        'duration': 61.6,
#        'distance': 447.7},
#       {'geometry': 'ubmyHjfYFHHH',
#        'maneuver': {'bearing_after': 215,
#         'bearing_before': 147,
#         'location': [-0.134298, 51.51803],
#         'modifier': 'right',
#         'type': 'end of road'},
#        'mode': 'driving',
#        'driving_side': 'right',
#        'name': 'Rathbone Street',
#        'intersections': [{'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [60, 210, 330],
#          'location': [-0.134298, 51.51803]}],
#        'weight': 4.2,
#        'duration': 4.2,
#        'distance': 12.4},
#       {'geometry': 'cbmyH~fYDCf@m@d@g@XUROxBiB`Au@DELK',
#        'maneuver': {'bearing_after': 144,
#         'bearing_before': 215,
#         'location': [-0.134401, 51.517939],
#         'modifier': 'left',
#         'type': 'turn'},
#        'mode': 'driving',
#        'driving_side': 'right',
#        'name': 'Rathbone Place',
#        'intersections': [{'out': 1,
#          'in': 0,
#          'entry': [True, True, True],
#          'bearings': [30, 150, 240],
#          'location': [-0.134401, 51.517939]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [45, 150, 330],
#          'location': [-0.133951, 51.517522]}],
#        'weight': 34.9,
#        'duration': 34.9,
#        'distance': 216.4},
#       {'geometry': 'qwlyHl}XAW?O?EEaAC{@E}@KyCC_@?M?W?i@',
#        'maneuver': {'bearing_after': 81,
#         'bearing_before': 151,
#         'location': [-0.132867, 51.516246],
#         'modifier': 'left',
#         'type': 'turn'},
#        'mode': 'driving',
#        'ref': 'A40',
#        'driving_side': 'right',
#        'name': 'Oxford Street',
#        'intersections': [{'out': 0,
#          'in': 3,
#          'entry': [True, False, False, False],
#          'bearings': [90, 150, 255, 330],
#          'location': [-0.132867, 51.516246]}],
#        'weight': 28.5,
#        'duration': 28.5,
#        'distance': 174.1},
#       {'geometry': 'sxlyHxmX?UA[ASAMASEe@Eg@Gs@C[CWC[E[KkAC]Iw@Eo@AOIiAAKAQCW',
#        'maneuver': {'bearing_after': 80,
#         'bearing_before': 90,
#         'location': [-0.130369, 51.516415],
#         'modifier': 'straight',
#         'type': 'new name'},
#        'mode': 'driving',
#        'ref': 'A40',
#        'driving_side': 'right',
#        'name': 'New Oxford Street',
#        'intersections': [{'out': 0,
#          'in': 2,
#          'entry': [True, False, False, True],
#          'bearings': [75, 180, 270, 345],
#          'location': [-0.130369, 51.516415]},
#         {'out': 0,
#          'in': 1,
#          'entry': [True, False, False],
#          'bearings': [75, 255, 345],
#          'location': [-0.129456, 51.516517]},
#         {'out': 0,
#          'in': 2,
#          'entry': [True, False, False],
#          'bearings': [75, 165, 255],
#          'location': [-0.128939, 51.5166]},
#         {'out': 0,
#          'in': 1,
#          'entry': [True, False, True],
#          'bearings': [75, 255, 330],
#          'location': [-0.127608, 51.516808]},
#         {'out': 0,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [75, 135, 255],
#          'location': [-0.127534, 51.516818]}],
#        'weight': 43.4,
#        'duration': 43.4,
#        'distance': 247.3},
#       {'geometry': 'u{lyH`xWFGFEBCDAZWRQ\\[DCDEFEBAB?D?RFTLTJDBB@DBB@@@DBNLJHHFDBHDPFNDTDFBFBLHPNXXdBlBFFJLz@fAn@~@@?b@n@DFJN@@DFDFPT',
#        'maneuver': {'bearing_after': 151,
#         'bearing_before': 75,
#         'location': [-0.126891, 51.516913],
#         'modifier': 'right',
#         'type': 'turn'},
#        'mode': 'driving',
#        'ref': 'A400',
#        'driving_side': 'right',
#        'name': 'Shaftesbury Avenue',
#        'intersections': [{'out': 1,
#          'in': 2,
#          'entry': [True, True, False, True],
#          'bearings': [75, 150, 255, 330],
#          'location': [-0.126891, 51.516913]},
#         {'out': 0,
#          'in': 2,
#          'entry': [True, False, False],
#          'bearings': [150, 240, 330],
#          'location': [-0.126665, 51.516639]},
#         {'out': 1,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [15, 210, 300],
#          'location': [-0.126538, 51.515869]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, False, True, True],
#          'bearings': [30, 75, 210, 255],
#          'location': [-0.126677, 51.515679]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, False, True],
#          'bearings': [15, 120, 195],
#          'location': [-0.12696, 51.515132]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True, True],
#          'bearings': [30, 135, 210, 315],
#          'location': [-0.127813, 51.514288]},
#         {'out': 1,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [30, 225, 330],
#          'location': [-0.128243, 51.513932]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [45, 120, 225],
#          'location': [-0.128924, 51.513407]}],
#        'weight': 79.2,
#        'duration': 79.2,
#        'distance': 472.8},
#       {'geometry': 'ydlyH~eXVMJGHEXOFCJGPIDCFCZOt@a@HEJEPELCB?LAXAF?P@R?@?H?V@P?F?H@\\?B@N?b@AZ?FAVEPCXMb@UXU@Af@u@P_@DKDKDIBGDELIJCFCFA@?RANCTCJ?PED?H?HAN?D?LAHC^ATGPELCD?FAVE',
#        'maneuver': {'bearing_after': 158,
#         'bearing_before': 217,
#         'location': [-0.129123, 51.513254],
#         'modifier': 'left',
#         'type': 'turn'},
#        'mode': 'driving',
#        'ref': 'A400',
#        'driving_side': 'right',
#        'name': 'Charing Cross Road',
#        'intersections': [{'out': 1,
#          'in': 0,
#          'entry': [False, True, True, False],
#          'bearings': [45, 165, 225, 345],
#          'location': [-0.129123, 51.513254]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [90, 165, 345],
#          'location': [-0.128843, 51.512789]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [0, 90, 180],
#          'location': [-0.12838, 51.511856]},
#         {'out': 1,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [0, 180, 270],
#          'location': [-0.128372, 51.51169]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, False, True],
#          'bearings': [0, 60, 180],
#          'location': [-0.128389, 51.511322]},
#         {'out': 0,
#          'in': 2,
#          'entry': [True, False, False],
#          'bearings': [165, 225, 345],
#          'location': [-0.128273, 51.510187]},
#         {'out': 0,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [135, 255, 330],
#          'location': [-0.128042, 51.509866]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [60, 135, 315],
#          'location': [-0.127441, 51.509493]},
#         {'out': 1,
#          'in': 2,
#          'entry': [False, True, False],
#          'bearings': [60, 165, 315],
#          'location': [-0.12737, 51.509439]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True, False],
#          'bearings': [0, 90, 180, 240],
#          'location': [-0.12718, 51.508574]}],
#        'weight': 111.9,
#        'duration': 111.9,
#        'distance': 641.1},
#       {'geometry': 'wbkyHxxWHBF@PNFFJLJL',
#        'maneuver': {'bearing_after': 199,
#         'bearing_before': 170,
#         'location': [-0.127012, 51.507804],
#         'modifier': 'right',
#         'type': 'turn'},
#        'mode': 'driving',
#        'ref': 'A4',
#        'driving_side': 'right',
#        'name': 'Strand',
#        'intersections': [{'out': 1,
#          'in': 3,
#          'entry': [False, True, False, False],
#          'bearings': [45, 195, 240, 345],
#          'location': [-0.127012, 51.507804]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, False, True],
#          'bearings': [15, 45, 210],
#          'location': [-0.127116, 51.507622]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [30, 165, 210],
#          'location': [-0.12716, 51.50758]}],
#        'weight': 11.1,
#        'duration': 11.1,
#        'distance': 43.4},
#       {'geometry': 's`kyHrzW@CH@F@DBFDFJ',
#        'maneuver': {'exit': 2,
#         'bearing_after': 142,
#         'bearing_before': 215,
#         'location': [-0.127296, 51.507463],
#         'modifier': 'left',
#         'type': 'rotary'},
#        'mode': 'driving',
#        'ref': 'A3212',
#        'driving_side': 'right',
#        'name': 'Whitehall',
#        'intersections': [{'out': 1,
#          'in': 0,
#          'entry': [False, True, False],
#          'bearings': [30, 150, 330],
#          'location': [-0.127296, 51.507463]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, False],
#          'bearings': [120, 180, 330],
#          'location': [-0.12728, 51.50745]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, False, True],
#          'bearings': [30, 90, 225],
#          'location': [-0.12735, 51.507293]}],
#        'rotary_name': 'Charing Cross',
#        'weight': 4.4,
#        'duration': 4.4,
#        'distance': 26.7},
#       {'geometry': 'i_kyHh{WNDH?t@GJEZK`@Oh@WLGHQFCFCJG\\Od@QD@DDTIRGFUTIf@OHCZK^MRG\\Gb@ILCZCt@EhAGDAd@EH?\\ABAXAPAP@Z?J?J@',
#        'maneuver': {'exit': 2,
#         'bearing_after': 174,
#         'bearing_before': 220,
#         'location': [-0.127412, 51.507249],
#         'modifier': 'left',
#         'type': 'exit rotary'},
#        'mode': 'driving',
#        'ref': 'A3212',
#        'driving_side': 'right',
#        'name': 'Whitehall',
#        'intersections': [{'out': 1,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [45, 180, 225],
#          'location': [-0.127412, 51.507249]},
#         {'out': 1,
#          'in': 0,
#          'entry': [False, True, False],
#          'bearings': [0, 165, 315],
#          'location': [-0.127396, 51.506851]},
#         {'lanes': [{'valid': True, 'indications': ['straight', 'left']},
#           {'valid': True, 'indications': ['straight']}],
#          'out': 1,
#          'in': 3,
#          'entry': [False, True, False, False],
#          'bearings': [60, 165, 255, 345],
#          'location': [-0.126897, 51.506009]},
#         {'out': 1,
#          'in': 2,
#          'entry': [True, True, True, False],
#          'bearings': [66, 165, 342, 345],
#          'location': [-0.126769, 51.50561]},
#         {'lanes': [{'valid': False, 'indications': ['left']},
#           {'valid': True, 'indications': ['straight']}],
#          'out': 1,
#          'in': 3,
#          'entry': [True, True, False, False],
#          'bearings': [75, 165, 210, 345],
#          'location': [-0.126357, 51.504855]},
#         {'lanes': [{'valid': False, 'indications': ['left']},
#           {'valid': True, 'indications': ['straight']}],
#          'out': 1,
#          'in': 2,
#          'entry': [False, True, False],
#          'bearings': [30, 165, 345],
#          'location': [-0.126293, 51.504698]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True, True],
#          'bearings': [0, 90, 180, 285],
#          'location': [-0.126008, 51.503154]}],
#        'weight': 88,
#        'duration': 88,
#        'distance': 557.8},
#       {'geometry': 'aajyHlrW^?D@T?RDvAJhAFH?D@R?B?',
#        'maneuver': {'bearing_after': 181,
#         'bearing_before': 181,
#         'location': [-0.125986, 51.502407],
#         'modifier': 'straight',
#         'type': 'new name'},
#        'mode': 'driving',
#        'ref': 'A3212',
#        'driving_side': 'right',
#        'name': 'Parliament Street',
#        'intersections': [{'out': 1,
#          'in': 0,
#          'entry': [False, True],
#          'bearings': [0, 180],
#          'location': [-0.125986, 51.502407]},
#         {'out': 1,
#          'in': 0,
#          'entry': [False, True, True],
#          'bearings': [0, 195, 270],
#          'location': [-0.126001, 51.502105]},
#         {'out': 2,
#          'in': 0,
#          'entry': [False, True, True, False],
#          'bearings': [15, 90, 180, 270],
#          'location': [-0.12603, 51.502011]}],
#        'weight': 31.4,
#        'duration': 31.4,
#        'distance': 157.2},
#       {'geometry': 'gxiyHjsW@y@?K@w@@u@?Q@uA',
#        'maneuver': {'bearing_after': 92,
#         'bearing_before': 182,
#         'location': [-0.126141, 51.500998],
#         'modifier': 'left',
#         'type': 'turn'},
#        'mode': 'driving',
#        'ref': 'A302',
#        'driving_side': 'right',
#        'name': 'Bridge Street',
#        'intersections': [{'lanes': [{'valid': True, 'indications': ['left']},
#           {'valid': False, 'indications': ['straight']},
#           {'valid': False, 'indications': ['straight']}],
#          'out': 1,
#          'in': 0,
#          'entry': [False, True, True, False],
#          'bearings': [0, 90, 180, 285],
#          'location': [-0.126141, 51.500998]}],
#        'weight': 15.8,
#        'duration': 15.8,
#        'distance': 98.2},
#       {'geometry': '_xiyHnjW',
#        'maneuver': {'bearing_after': 0,
#         'bearing_before': 92,
#         'location': [-0.124724, 51.50096],
#         'modifier': 'right',
#         'type': 'arrive'},
#        'mode': 'driving',
#        'ref': 'A302',
#        'driving_side': 'right',
#        'name': 'Bridge Street',
#        'intersections': [{'in': 0,
#          'entry': [True],
#          'bearings': [272],
#          'location': [-0.124724, 51.50096]}],
#        'weight': 0,
#        'duration': 0,
#        'distance': 0}],
#      'summary': 'Charing Cross Road, Whitehall',
#      'weight': 543.2,
#      'duration': 543.2,
#      'distance': 3226.9}],
#    'weight_name': 'routability',
#    'weight': 543.2,
#    'duration': 543.2,
#    'distance': 3226.9}],
#  'waypoints': [{'hint': 'g8zxgB1A3oMCAAAAIAAAABAAAAAqAAAAufKbP-ULTkGj8jNB9t2KQQIAAAAgAAAAEAAAACoAAAAv7QAAq-v9_6QpEgMW7P3_0ikSAwMAHwmsq162',
#    'distance': 9.019046,
#    'name': 'Howland Mews East',
#    'location': [-0.136277, 51.521956]},
#   {'hint': 'dRYAgKiHwIgLAAAAKQAAADkAAAAkAAAAWN0AQY_k6UHjb9BB1NLKQQsAAAApAAAAOQAAACQAAAAv7QAAzBj-_6DXEQOoGP7__NQRAwUA_xCsq162',
#    'distance': 75.252458,
#    'name': 'Bridge Street',
#    'location': [-0.124724, 51.50096]}]}

# %%
def get_route(pickup_lon, pickup_lat, dropoff_lon, dropoff_lat, url=url_server_osm_driving, mode = 'driving'):
    
    loc = "{},{};{},{}".format(pickup_lon, pickup_lat, dropoff_lon, dropoff_lat)
    r = requests.get("{}/route/v1/{}/{}".format(url, mode, loc))
    if r.status_code!= 200:
        return {}
  
    res = r.json()   
    routes = polyline.decode(res['routes'][0]['geometry'])
    start_point = [res['waypoints'][0]['location'][1], res['waypoints'][0]['location'][0]]
    end_point = [res['waypoints'][1]['location'][1], res['waypoints'][1]['location'][0]]
    distance = res['routes'][0]['distance']
    
    out = {'route':routes,
           'start_point':start_point,
           'end_point':end_point,
           'distance':distance
          }

    return out

# %%
test_route = get_route(long_start, lat_start, long_end, lat_end)
test_route
# Out:
# {'route': [(51.52196, -0.13628),
#   (51.52142, -0.13778),
#   (51.51803, -0.1343),
#   (51.51625, -0.13287),
#   (51.51691, -0.12689),
#   (51.51629, -0.12636),
#   (51.51506, -0.12701),
#   (51.51325, -0.12912),
#   (51.51195, -0.12839),
#   (51.51032, -0.12834),
#   (51.50923, -0.12727),
#   (51.5078, -0.12701),
#   (51.50712, -0.12744),
#   (51.5042, -0.12614),
#   (51.501, -0.12614),
#   (51.50096, -0.12472)],
#  'start_point': [51.521956, -0.136277],
#  'end_point': [51.50096, -0.124724],
#  'distance': 3226.9}

# %%
def get_map(route):
    
    m = folium.Map(location=[(route['start_point'][0] + route['end_point'][0])/2, 
                             (route['start_point'][1] + route['end_point'][1])/2], 
                   zoom_start=13)

    folium.PolyLine(
        route['route'],
        weight=8,
        color='blue',
        opacity=0.6
    ).add_to(m)

    folium.Marker(
        location=route['start_point'],
        icon=folium.Icon(icon='play', color='green')
    ).add_to(m)

    folium.Marker(
        location=route['end_point'],
        icon=folium.Icon(icon='stop', color='red')
    ).add_to(m)

    return m

# %%
# driving
get_map(get_route(long_start, lat_start, long_end, lat_end, url = url_server_osm_driving, mode = 'driving'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddecdbd8e69291a8ed12ea016af6ab58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddecdbd8e69291a8ed12ea016af6ab58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ddecdbd8e69291a8ed12ea016af6ab58 = L.map(
#                 &quot;map_ddecdbd8e69291a8ed12ea016af6ab58&quot;,
#                 {
#                     center: [51.511458000000005, -0.13050050000000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bce9fce46369804b4deb0fca70db045 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ddecdbd8e69291a8ed12ea016af6ab58);
#
#
#             var poly_line_f8169f0fe5c4577ecd90c44c4a3b1224 = L.polyline(
#                 [[51.52196, -0.13628], [51.52142, -0.13778], [51.51803, -0.1343], [51.51625, -0.13287], [51.51691, -0.12689], [51.51629, -0.12636], [51.51506, -0.12701], [51.51325, -0.12912], [51.51195, -0.12839], [51.51032, -0.12834], [51.50923, -0.12727], [51.5078, -0.12701], [51.50712, -0.12744], [51.5042, -0.12614], [51.501, -0.12614], [51.50096, -0.12472]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_ddecdbd8e69291a8ed12ea016af6ab58);
#
#
#             var marker_7f04191f40b4dbf1b2925b360bda0839 = L.marker(
#                 [51.521956, -0.136277],
#                 {}
#             ).addTo(map_ddecdbd8e69291a8ed12ea016af6ab58);
#
#
#             var icon_0a5e970705cde56b2f7f4ca8fca7180c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;play&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f04191f40b4dbf1b2925b360bda0839.setIcon(icon_0a5e970705cde56b2f7f4ca8fca7180c);
#
#
#             var marker_f079db1014f77ac2e7cdf87b03cd989f = L.marker(
#                 [51.50096, -0.124724],
#                 {}
#             ).addTo(map_ddecdbd8e69291a8ed12ea016af6ab58);
#
#
#             var icon_2b9be34f918fa7ef8ce38badb3a7825f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;stop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f079db1014f77ac2e7cdf87b03cd989f.setIcon(icon_2b9be34f918fa7ef8ce38badb3a7825f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
get_map(get_route(long_start, lat_start, long_end, lat_end, url = url_server_osm_cycle, mode = 'biking'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c8e9d7a7be85366e238cacba3eca49b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c8e9d7a7be85366e238cacba3eca49b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6c8e9d7a7be85366e238cacba3eca49b = L.map(
#                 &quot;map_6c8e9d7a7be85366e238cacba3eca49b&quot;,
#                 {
#                     center: [51.511167, -0.1304265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_749891142a94457d444f0bfb5a474652 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c8e9d7a7be85366e238cacba3eca49b);
#
#
#             var poly_line_3a0d8eadad0b2d741067f6e6c431a3cf = L.polyline(
#                 [[51.52206, -0.13623], [51.52187, -0.13681], [51.51893, -0.13367], [51.51847, -0.13474], [51.51794, -0.1344], [51.51565, -0.13244], [51.51579, -0.13187], [51.51276, -0.12997], [51.51341, -0.12892], [51.51269, -0.12764], [51.51268, -0.12715], [51.50953, -0.12694], [51.50944, -0.12737], [51.5078, -0.12701], [51.50712, -0.12744], [51.5042, -0.12614], [51.49964, -0.12616], [51.49831, -0.12574], [51.4984, -0.12491], [51.50027, -0.12462]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8}
#             ).addTo(map_6c8e9d7a7be85366e238cacba3eca49b);
#
#
#             var marker_9da0c701fb826042b772d0b34f9f9473 = L.marker(
#                 [51.522061, -0.136232],
#                 {}
#             ).addTo(map_6c8e9d7a7be85366e238cacba3eca49b);
#
#
#             var icon_097a765e5936548e7e5ac39ce9d8e321 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;play&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9da0c701fb826042b772d0b34f9f9473.setIcon(icon_097a765e5936548e7e5ac39ce9d8e321);
#
#
#             var marker_12858848d2b8c9c1ee5f62b656c0ecc2 = L.marker(
#                 [51.500273, -0.124621],
#                 {}
#             ).addTo(map_6c8e9d7a7be85366e238cacba3eca49b);
#
#
#             var icon_8b44985cba2b9b054698bcd30816003b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;stop&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_12858848d2b8c9c1ee5f62b656c0ecc2.setIcon(icon_8b44985cba2b9b054698bcd30816003b);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## References
#
# 1. [Plotting OSRM routes](https://www.thinkdatascience.com/post/2020-03-03-osrm/osrm/)
# 1. [Explaining request and response](https://medium.com/ivymobility-developers/open-source-routing-machine-43db9ae06fb7)
# 1. [A tutorial in Chinese and Zhihu](https://zhuanlan.zhihu.com/p/386900671)
# 1. [OSRM wiki: running multiple profiles on one machine](https://github.com/Project-OSRM/osrm-backend/wiki/Running-OSRM#running-multiple-profiles-on-one-machine)
